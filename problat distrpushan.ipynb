# %%
import numpy as np
from scipy.stats import binom
binom.pmf(p=0.5,k=2,n=5)
# Out:
# np.float64(0.31249999999999983)

# %%
binom.pmf(p=0.5,k=0,n=5)
# Out:
# np.float64(0.031249999999999976)

# %%
binom.cdf(p=0.5,k=2,n=5)
# Out:
# np.float64(0.5)

# %%
from numpy import random 
import  matplotlib.pyplot as plt
import seaborn as sns
x = random.binomial(n=10, p=0.5, size=1000)  
sns.histplot(x, kde=True)  
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np
mu, sigma = 0.5, 0.1
s = np.random.normal(mu, sigma, 1000)  # Create the bins and histogram
n,bins, p= plt.hist(s, 20, density=True)  # Plot the distribution curve
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( -(bins - mu)**2 / (2 *  sigma**2) ), linewidth=3, color='y')
plt.show()

# %%
import numpy as np
b=np.random.binomial(n=10,p=0.2,size=100)
b
# Out:
# array([2, 6, 1, 3, 1, 3, 2, 0, 0, 2, 2, 3, 0, 1, 1, 4, 2, 4, 2, 1, 4, 1,
#        0, 1, 1, 2, 1, 0, 2, 1, 2, 1, 3, 3, 1, 4, 1, 1, 0, 1, 0, 1, 2, 2,
#        1, 3, 1, 4, 4, 2, 3, 2, 2, 1, 4, 3, 0, 5, 3, 0, 1, 0, 5, 2, 4, 1,
#        2, 1, 3, 1, 3, 4, 0, 1, 0, 4, 2, 3, 2, 2, 3, 1, 2, 3, 1, 2, 2, 3,
#        1, 5, 1, 0, 3, 3, 3, 1, 1, 3, 1, 3], dtype=int32)

# %%
import statsmodels.api  as sm

# %%
sm.qqplot(b,line='45')
import matplotlib.pyplot as plt
plt.show()

# %%
n=np.random.normal(0,1,100)
sm.qqplot(n,line='45')
plt.show()

# %%
import pandas as pd
t=pd.read_csv("netflix_titles.csv")
t
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 import pandas as pd
# ----> 2 t=pd.read_csv("netflix_titles.csv")
#       3 t
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...
