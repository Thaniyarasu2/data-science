# %%
import pandas as pd

# %%
d=pd.read_csv("test (1).csv")
d
# Out:
#          id                                              title  Rating  \
# 0      2242                            Casuals For Men  (Blue)     3.8
# 1     20532                           Women Black Flats Sandal     3.9
# 2     10648                           Women Gold Wedges Sandal     3.9
# 3     20677  Men's Height Increasing High Heel Formal Party...     3.9
# 4     12593                             Loafers For Men  (Tan)     3.9
# ...     ...                                                ...     ...
# 5239  14033                       Women Off White Flats Sandal     NaN
# 5240    297                             Slip On For Men  (Tan)     3.9
# 5241  18733                            Women Grey Heels Sandal     3.8
# 5242   6162  Womens Casual Comfort Stylish Black High Heel ...     3.9
# 5243  13574    ZAPATOZ Women's Casual PU Leather Sneaker Shoes     3.9
#
#      maincateg  platform  actprice1  norating1  noreviews1  star_5f  star_4f  \
# ...

# %%
d.columns
# Out:
# Index(['id', 'title', 'Rating', 'maincateg', 'platform', 'actprice1',
#        'norating1', 'noreviews1', 'star_5f', 'star_4f', 'star_3f', 'star_2f',
#        'star_1f', 'fulfilled1'],
#       dtype='object')

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5244 entries, 0 to 5243
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          5244 non-null   int64
#  1   title       5244 non-null   object
#  2   Rating      5041 non-null   float64
#  3   maincateg   5177 non-null   object
#  4   platform    5244 non-null   object
#  5   actprice1   5244 non-null   int64
#  6   norating1   5244 non-null   int64
#  7   noreviews1  5244 non-null   int64
#  8   star_5f     5176 non-null   float64
#  9   star_4f     5244 non-null   int64
#  10  star_3f     5244 non-null   int64
#  11  star_2f     5244 non-null   int64
#  12  star_1f     5058 non-null   float64
#  13  fulfilled1  5244 non-null   int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 573.7+ KB

# %%
d.isnull().sum()
# Out:
# id              0
# title           0
# Rating        203
# maincateg      67
# platform        0
# actprice1       0
# norating1       0
# noreviews1      0
# star_5f        68
# star_4f         0
# star_3f         0
# star_2f         0
# star_1f       186
# fulfilled1      0
# dtype: int64

# %%
ns=d.select_dtypes("int64","float64")
ns
# Out:
#          id  actprice1  norating1  noreviews1  star_4f  star_3f  star_2f  \
# 0      2242        999      27928        3543     4295     3457     1962
# 1     20532        499       3015         404      657      397      182
# 2     10648        999        449          52       70       71       33
# 3     20677       2999        290          40       51       49       17
# 4     12593        999       2423         326      414      293      143
# ...     ...        ...        ...         ...      ...      ...      ...
# 5239  14033        699       1235         153      323      155       62
# 5240    297       1993        329          56       37       60        5
# 5241  18733        999       1280         135      290      172       94
# 5242   6162        499       4867         574      974      648      328
# 5243  13574        749          8           5        0        0        0
#
#       fulfilled1
# 0              1
# 1              1
# 2              1
# 3              1
# ...

# %%
ns.corr()
# Out:
#                   id  actprice1  norating1  noreviews1   star_4f   star_3f  \
# id          1.000000   0.017346  -0.005400   -0.006166 -0.004093 -0.007262
# actprice1   0.017346   1.000000  -0.067529   -0.064513 -0.059661 -0.070007
# norating1  -0.005400  -0.067529   1.000000    0.995372  0.980808  0.987718
# noreviews1 -0.006166  -0.064513   0.995372    1.000000  0.985507  0.985558
# star_4f    -0.004093  -0.059661   0.980808    0.985507  1.000000  0.956674
# star_3f    -0.007262  -0.070007   0.987718    0.985558  0.956674  1.000000
# star_2f    -0.002321  -0.081037   0.967278    0.948874  0.912031  0.967236
# fulfilled1 -0.008975   0.236018   0.103945    0.097584  0.101222  0.097155
#
#              star_2f  fulfilled1
# id         -0.002321   -0.008975
# actprice1  -0.081037    0.236018
# norating1   0.967278    0.103945
# noreviews1  0.948874    0.097584
# star_4f     0.912031    0.101222
# star_3f     0.967236    0.097155
# star_2f     1.000000    0.102702
# ...

# %%
x=d[["actprice1","norating1","fulfilled1"]]

# %%
from sklearn.preprocessing import StandardScaler

# %%
d=StandardScaler()

# %%
x=d.fit_transform(x)
x
# Out:
# array([[-0.29649007,  1.93628654,  0.80886258],
#        [-0.68696011,  0.00205123,  0.80886258],
#        [-0.29649007, -0.19717198,  0.80886258],
#        ...,
#        [-0.29649007, -0.13265347, -1.23630395],
#        [-0.68696011,  0.14583977, -1.23630395],
#        [-0.49172509, -0.23141104,  0.80886258]], shape=(5244, 3))

# %%
from sklearn.neighbors import NearestNeighbors

# %%
model=NearestNeighbors(n_neighbors=6,metric="euclidean")
model.fit(x)
# Out:
# NearestNeighbors(metric='euclidean', n_neighbors=6)

# %%
x=["actprice1","Rating","fulfilled1"]

# %%
#d["platform"].unique()

# %%
def rec(plat):
    d_index =d[d["platform"] ==plat].index[0]
    
    query_point =s.loc[[s_index], x].values
   
    distances, indices = model.kneighbors(query_point)
    
    return s.iloc[indices[0]]["platform"]

# 3. Test it
print(rec("Amazon"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 11
#       8     return s.iloc[indices[0]]["platform"]
#      10 # 3. Test it
# ---> 11 print(rec("Amazon"))
#
# Cell In[17], line 2, in rec(plat)
#       1 def rec(plat):
# ----> 2     d_index =d[d["platform"] ==plat].index[0]
#       4     query_point =s.loc[[s_index], x].values
#       6     distances, indices = model.kneighbors(query_point)
#
# TypeError: 'StandardScaler' object is not subscriptable
